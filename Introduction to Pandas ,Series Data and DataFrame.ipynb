# %% [markdown]
# ### Introduction to Pandas ,Series Data and DataFrame

# %%
import pandas as pd
import warnings
warnings.filterwarnings(action= "ignore")

# %%
student = ["Alice", "Jack", "Molly"]
pd.Series(student)
# Out:
# 0    Alice
# 1     Jack
# 2    Molly
# dtype: object

# %%
num = [1,2,3,4,5]
pd.Series(num)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
student = ["Alice", "Jack", None]
pd.Series(student)
# Out:
# 0    Alice
# 1     Jack
# 2     None
# dtype: object

# %%
num = [1,2,3,4,None]  # None 값이 있기때문에 dtype이 float
pd.Series(num)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# dtype: float64

# %%
# keep in mind when see NaN, it's meaning is similar to None , but it's a numeric value and treated diffently for efficiency reasons.

import numpy as np
print(np.nan == None)
print(np.nan ==np.nan)
print(np.isnan(np.nan))
# Out:
# False
# False
# True

# %%
students_scores = {'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English'}
s = pd.Series(students_scores)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
s.index
# Out:
# Index(['Alice', 'Jack', 'Molly'], dtype='object')

# %%
# the dtype of object is not just for strings, but for arbitrary objects.
students = [("Alice","Brown"), ("Jack", "White"), ("Molly", "Green")]
pd.Series(students)
# Out:
# 0    (Alice, Brown)
# 1     (Jack, White)
# 2    (Molly, Green)
# dtype: object

# %%
s = pd.Series(['Physics', 'Chemistry', 'English'], index=['Alice', 'Jack', 'Molly'])
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
students_scores = {'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English'}

s = pd.Series(students_scores, index=['Alice', 'Molly', 'Sam'])
s
# Out:
# Alice    Physics
# Molly    English
# Sam          NaN
# dtype: object

# %% [markdown]
# ### Querying a Series

# %%
# To query by numeric location, starting at zero, use the iloc attribute. To query by the index label

students_classes = {'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English',
                   'Sam': 'History'}
s = pd.Series(students_classes)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
s.iloc[1]
# Out:
# 'Chemistry'

# %%
s.loc["Jack"]
# Out:
# 'Chemistry'

# %%
# Keep in mind that iloc and loc are not methods, they are attributes. So you don't use 
# parentheses to query them, but square brackets instead, which is called the indexing operator. 
# Pandas tries to make our code a bit more readable and provides a sort of smart syntax using 
# the indexing operator directly on the series itself.
print(s[1])
print(s["Jack"])
# Out:
# Chemistry
# Chemistry

# %%
grades = pd.Series([90, 80, 70, 60])

total = 0
for grade in grades:
    total+=grade
print(total/len(grades))
# Out:
# 75.0

# %%
import numpy as np

# Then we just call np.sum and pass in an iterable item. In this case, our panda series.

total = np.sum(grades)
print(total/len(grades))
# Out:
# 75.0

# %%
num = pd.Series(np.random.randint(0,1000,10000))

# %%
# %%timeit -n 100
total = 0
for number in num:
    total+=number

total/len(num)
# Out:
# 1.22 ms ± 18.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total = np.sum(num)
total/len(num)
# Out:
# 64.9 µs ± 5.88 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
num+=2
num.head()
# Out:
# 0    477
# 1    256
# 2    844
# 3    252
# 4    708
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))

for label, value in s.iteritems():
    s.loc[label]= value+2
# Out:
# 42.3 ms ± 2.04 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,1000))
s+=2
# Out:
# 304 µs ± 59.9 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
a= pd.Series([1,2,3])
a["apple"] = 5
a
# Out:
# 0        1
# 1        2
# 2        3
# apple    5
# dtype: int64

# %%
students_classes = pd.Series({'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English',
                   'Sam': 'History'})
students_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
kelly_classes = pd.Series(['Philosophy', 'Arts', 'Math'], index=['Kelly', 'Kelly', 'Kelly'])
kelly_classes
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
all_students_classes = students_classes.append(kelly_classes)
all_students_classes
# Out:
# Alice       Physics
# Jack      Chemistry
# Molly       English
# Sam         History
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %% [markdown]
# ### DataFrame Data Structure

# %%
record1 = pd.Series({'Name': 'park',
                        'Class': 'Physics',
                        'Score': 85})
record2 = pd.Series({'Name': 'Jack',
                        'Class': 'Chemistry',
                        'Score': 82})
record3 = pd.Series({'Name': 'kim',
                        'Class': 'Biology',
                        'Score': 90})

# %%
df = pd.DataFrame([record1, record2 ,record3] , index = ['A','B',"C"])

# %%
df.head()
# Out:
#    Name      Class  Score
# A  park    Physics     85
# B  Jack  Chemistry     82
# C   kim    Biology     90

# %%
students = [{'Name': 'Alice',
              'Class': 'Physics',
              'Score': 85},
            {'Name': 'Jack',
             'Class': 'Chemistry',
             'Score': 82},
            {'Name': 'Helen',
             'Class': 'Biology',
             'Score': 90}]


df = pd.DataFrame(students, index=['school1', 'school2', 'school1'])

df.head()
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
df.loc["school2"]
# Out:
# Name          Jack
# Class    Chemistry
# Score           82
# Name: school2, dtype: object

# %%
df.loc["school1"]
# Out:
#           Name    Class  Score
# school1  Alice  Physics     85
# school1  Helen  Biology     90

# %%
df.loc["school1","Score"]
# Out:
# school1    85
# school1    90
# Name: Score, dtype: int64

# %%
# transpose
df.T
# Out:
#        school1    school2  school1
# Name     Alice       Jack    Helen
# Class  Physics  Chemistry  Biology
# Score       85         82       90

# %%
# columns selection
df[["Name", "Class"]]
# Out:
#           Name      Class
# school1  Alice    Physics
# school2   Jack  Chemistry
# school1  Helen    Biology

# %%
df.loc["school2"]["Score"]
# Out:
# 82

# %%
#loc does row selection, and it can take two parameters, the row index and the list of column names.
#Slicing

df.loc[:,["Class","Score"]]
# Out:
#              Class  Score
# school1    Physics     85
# school2  Chemistry     82
# school1    Biology     90

# %%
copy_df  =  df.copy()
copy_df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistry     82
# school1  Helen    Biology     90

# %%
#the drop function doesn't change the DataFrame by default! Instead,
# the drop function returns to you a copy of the DataFrame with the given rows removed.

copy_df.drop("school1", inplace = True)

# %%
copy_df
# Out:
#          Name      Class  Score
# school2  Jack  Chemistry     82

# %%
#second way to drop a column, and that's directly through the use of the indexing 
# operator, using the del keyword. This way of dropping data, however, takes immediate effect 
# on the DataFrame and does not return a view.

del copy_df["Class"]
copy_df
# Out:
#          Name  Score
# school2  Jack     82

# %% [markdown]
# ### DataFrame Indexing and Loading

# %%
import os
os.chdir('C://Users//my/Desktop//')

# %%
df = pd.read_csv("corsera_dataset/Admission_Predict.csv")
df.head(3)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72

# %%
df = pd.read_csv("corsera_dataset/Admission_Predict.csv",index_col = 0)
df.head(3)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72

# %%
new_df=df.rename(columns={'GRE Score':'GRE Score', 'TOEFL Score':'TOEFL Score',
                   'University Rating':'University Rating', 
                   'SOP': 'Statement of Purpose','LOR': 'Letter of Recommendation',
                   'CGPA':'CGPA', 'Research':'Research',
                   'Chance of Admit':'Chance of Admit'})
new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65

# %%
new_df=new_df.rename(mapper=str.strip, axis='columns')

new_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
#
#             LOR  CGPA  Research  Chance of Admit
# Serial No.
# 1           4.5  9.65         1             0.92
# 2           4.5  8.87         1             0.76
# 3           3.5  8.00         1             0.72
# 4           2.5  8.67         1             0.80
# 5           3.0  8.21         0             0.65

# %%
cols = list(df.columns)

cols = [x.lower().strip() for x in cols]
df.columns=cols

df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %% [markdown]
# ### Querying a DataFrame

# %% [markdown]
# A Boolean mask is an array which can be of one dimension like a series, or two dimensions like a data frame, where each of the values in the array are either true or false. This array is essentially overlaid on top of the data structure that we're querying.

# %%
df.head(3)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72

# %%
df_admit =  df["chance of admit"] > 0.7

# %%
df[df_admit].head(3)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72

# %%
# So, what do you do with the boolean mask once you have formed it?  you can just lay it on top of the
# data to "hide" the data you don't want, which is represented by all of the False values. We do this by using
# the .where() function on the original DataFrame.

df.where(df_admit).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(df_admit).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
df[df["university rating"] >= 4.5].head(3)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 6                 330          115                  5  4.5  3.0  9.34
# 23                328          116                  5  5.0  5.0  9.50
# 24                334          119                  5  5.0  4.5  9.70
#
#             research  chance of admit
# Serial No.
# 6                  1             0.90
# 23                 1             0.94
# 24                 1             0.95

# %% [markdown]
# 객체간의 비교연산
# eq()  ==
#
# ne()  =!
#
# lt()  <
#
# qt()  >
#
# le()  <=
#
# ge()  >=

# %%
df['chance of admit'].gt(0.7) & df['chance of admit'].lt(0.9)
# Out:
# Serial No.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df[df['chance of admit'].gt(0.7).lt(0.9)].head(3)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 5                 314          103                  2  2.0  3.0  8.21
# 8                 308          101                  2  3.0  4.0  7.90
# 9                 302          102                  1  2.0  1.5  8.00
#
#             research  chance of admit
# Serial No.
# 5                  0             0.65
# 8                  0             0.68
# 9                  0             0.50

# %% [markdown]
# ### Indexing Dataframes

# %%
df = pd.read_csv("corsera_dataset/Admission_Predict.csv", index_col = 0 ) 
df.head(3)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72

# %%
df['Serial Number'] = df.index

df = df.set_index('Chance of Admit ')
df.head()
# Out:
#                   GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Chance of Admit
# 0.92                    337          118                  4  4.5   4.5  9.65
# 0.76                    324          107                  4  4.0   4.5  8.87
# 0.72                    316          104                  3  3.0   3.5  8.00
# 0.80                    322          110                  3  3.5   2.5  8.67
# 0.65                    314          103                  2  2.0   3.0  8.21
#
#                   Research  Serial Number
# Chance of Admit
# 0.92                     1              1
# 0.76                     1              2
# 0.72                     1              3
# 0.80                     1              4
# 0.65                     0              5

# %%
df = df.reset_index()
df.head(3)
# Out:
#    Chance of Admit   GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0              0.92        337          118                  4  4.5   4.5
# 1              0.76        324          107                  4  4.0   4.5
# 2              0.72        316          104                  3  3.0   3.5
#
#    CGPA  Research  Serial Number
# 0  9.65         1              1
# 1  8.87         1              2
# 2  8.00         1              3

# %%
df = pd.read_csv('corsera_dataset/census.csv')
df.head(3)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# ...

# %%
df["SUMLEV"].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
columns = ['STNAME','CTYNAME','BIRTHS2010','BIRTHS2011','BIRTHS2012','BIRTHS2013',
                   'BIRTHS2014','BIRTHS2015','POPESTIMATE2010','POPESTIMATE2011',
                   'POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']
df = df[columns]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 0  Alabama         Alabama       14226       59689       59062       57938
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0       58334       58305          4785161          4801108          4816089
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
#
# ...

# %%
df = df.set_index(['STNAME', 'CTYNAME'])
df.head(3)
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama              14226       59689       59062       57938
#         Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Alabama              58334       58305          4785161
#         Autauga County         623         600            54660
#         Baldwin County        2186        2240           183193
#
#                         POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME  CTYNAME
# Alabama Alabama                 4801108          4816089          4830533
#         Autauga County            55253            55175            55038
#         Baldwin County           186659           190396           195126
#
#                         POPESTIMATE2014  POPESTIMATE2015
# ...

# %%
df.loc['Michigan', 'Washtenaw County']
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880

# %%
df.loc[ [('Michigan', 'Washtenaw County'),
         ('Michigan', 'Wayne County')] ]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           345563
#          Wayne County           23607       23586          1815199
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County           349048           351213           354289
#          Wayne County              1801273          1792514          1775713
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           357029           358880
#          Wayne County              1766008          1759335

# %% [markdown]
# ### Missing Values

# %%
df = pd.read_csv("corsera_dataset/class_grades.csv")
df.head(3)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89

# %%
df.isnull().sum()
# Out:
# Prefix        0
# Assignment    7
# Tutorial      3
# Midterm       3
# TakeHome      5
# Final         3
# dtype: int64

# %%
df.fillna(0, inplace = True)
df.isnull().any()
# Out:
# Prefix        False
# Assignment    False
# Tutorial      False
# Midterm       False
# TakeHome      False
# Final         False
# dtype: bool

# %%
df = pd.read_csv('corsera_dataset/log.csv')
df.head(3)
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN

# %%
# The two common fill values are ffill and bfill. ffill is for forward
# filling and it updates an na value for a particular cell with the value from the previous row. bfill is
# backward filling, which is the opposite of ffill. It fills the missing values with the next valid value.
# It's important to note that your data needs to be sorted in order for this to have the effect you might
# want. Data which comes from traditional database management systems usually has no order guarantee, just
# like this data. So be careful.

# %%
df = df.set_index('time')
df = df.sort_index()
df.head(3)
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN

# %%
df = df.reset_index()
df = df.set_index(["time","user"])
df.head(5)
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN

# %%
df = df.fillna(method = 'ffill')
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %%
df = pd.DataFrame({'A': [1, 1, 2, 3, 4],
                   'B': [3, 6, 3, 8, 9],
                   'C': ['a', 'b', 'c', 'd', 'e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1, 100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
df.replace([1, 3], [100, 300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
df = pd.read_csv('corsera_dataset/log.csv')
df.head(3)
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN

# %%
# To replace using a regex we make the first parameter to replace the regex pattern we want to match, the
# second parameter the value we want to emit upon match, and then we pass in a third parameter "regex=True".

df.replace(to_replace=".*.html$", value="webpage", regex=True).head(3)
# Out:
#          time    user    video  playback position paused  volume
# 0  1469974424  cheryl  webpage                  5  False    10.0
# 1  1469974454  cheryl  webpage                  6    NaN     NaN
# 2  1469974544  cheryl  webpage                  9    NaN     NaN
